# %% [markdown]
# ## Example trackbars + HSV color segmentation
# Complet the following code. It provides a basic color segmentation method.

# %%
## A simple example TrackBar + HSV for color segmentation 

#import opencv and numpy 
import cv2
import numpy as np

# %%
#define a emty function
def empty(a):
    pass

# %%
#read an image
path = 'images/lambo.png'
....

# %%
#convert to HSV 
imgHSV =

#create a trackbars window size 640 x 240
................

#create 6 trackbars 
#H min  from 0 to 179 
#H max  from 19 to 179
#S min  from 110 to 255
#S max  from 240 to 255
#V min  from 153 to 255
#V max  from 255 to 255

.........


while True:
    # get the value from the trackbar cv2.getTrackbarPos()
    h_min = ....
    h_max = ....
    s_min = ....
    s_max = ...
    v_min = ...
    v_max = ...
    #define a range of color betwee min and max 
    lower = np.array([h_min,s_min,v_min])
    upper = np.array([h_max,s_max,v_max])
    #define a mask such that inside this range pixel is set to one cv2.inrange(input_image, min , max)
    mask = ...
    #do a AND operation between the original image and the mask 
    imgResult = ....

#show the images 
    cv2.imshow("Original",img)
    cv2.imshow("HSV",imgHSV)
    cv2.imshow("Mask", mask)
    cv2.imshow("Result", imgResult)

    if cv2.waitKey(1)&0xFF == 27:
        break
cv2.destroyAllWindows()
# Out:
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# 0 19 110 240 153 255
# ...
